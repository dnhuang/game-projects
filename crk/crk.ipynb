# %%
# necessary imports
import pandas as pd
import seaborn as sns
from scipy.interpolate import make_interp_spline
from matplotlib import pyplot as plt

# %%
exp_df = pd.read_csv("exp.csv")
exp_df.head()
# Out:
#    level   xp
# 0      2   60
# 1      3   80
# 2      4  100
# 3      5  120
# 4      6  150

# %%
plt.title('xp vs level')
sns.lineplot(data=exp_df, x='level', y='xp');
